# %% [markdown]
# # DEMO 3.2: **Decision Trees**
# <u>Nội dung</u>:
# 1. Phân lớp IRIS
# 2. Phân lớp Social_Network_Ads
#
# <u>Cập nhật</u>: **04/2023**

# %% [markdown]
# ---
# ### **MÔI TRƯỜNG TRIỂN KHAI ỨNG DỤNG**
# ---

# %%
pip install python-graphviz
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement python-graphviz (from versions: none)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: No matching distribution found for python-graphviz

# %%
import os
os.environ["PATH"] += os.pathsep + 'C:\Program Files (x86)\Graphviz2.38/bin/'

# %%
## Thư viện
import imageio
import joblib            as jlb
import matplotlib.pyplot as plt
import numpy             as np
import pandas            as pd
import pydotplus         as pdp
import seaborn           as sbn

from IPython.display         import Image  
from sklearn                 import tree
from sklearn.model_selection import train_test_split  
from sklearn.tree            import DecisionTreeClassifier

# %% [markdown]
# ---
# ## 1. **Phân lớp IRIS**
# ---

# %%
## Tập tin dữ liệu IRIS
data = pd.read_excel('./Data/Iris.xls')
print(data.head())
# Out:
#    sepallength  sepalwidth  petallength  petalwidth         iris
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
## Các features: sepallength, sepalwidth, petallength, petalwidth
X = data.drop('iris', axis = 1)
X.head()

## Biến target: iris
y = data.iris

print(pd.concat([X, y], axis = 1).head())
# Out:
#    sepallength  sepalwidth  petallength  petalwidth         iris
# 0          5.1         3.5          1.4         0.2  Iris-setosa
# 1          4.9         3.0          1.4         0.2  Iris-setosa
# 2          4.7         3.2          1.3         0.2  Iris-setosa
# 3          4.6         3.1          1.5         0.2  Iris-setosa
# 4          5.0         3.6          1.4         0.2  Iris-setosa

# %%
## Chia tập dữ liệu thành training, test sets theo tỷ lệ 80:20
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .2, random_state = 1)

# %%
##------------------------------------------------------------------------------
## Xây dựng mô hình Decision Tree
##------------------------------------------------------------------------------  
clf   = DecisionTreeClassifier() 
model = clf.fit(X, y) # huấn luyện để tạo  mô hình

# %%
## Biểu diễn cây quyết định
dcs_tree = tree.export_graphviz(clf, out_file = None, feature_names = X.columns)
graph    = pdp.graph_from_dot_data(dcs_tree)  
Image(graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# InvocationException                       Traceback (most recent call last)
# Cell In[18], line 4
#       2 dcs_tree = tree.export_graphviz(clf, out_file = None, feature_names = X.columns)
#       3 graph    = pdp.graph_from_dot_data(dcs_tree)
# ----> 4 Image(graph.create_png())
#
# File c:\Program Files\Python311\Lib\site-packages\pydotplus\graphviz.py:1797, in Dot.__init__.<locals>.<lambda>(f, prog)
#    1792 # Automatically creates all the methods enabling the creation
#    1793 # of output in any of the supported formats.
#    1794 for frmt in self.formats:
#    1795     self.__setattr__(
#    1796         'create_' + frmt,
# -> 1797         lambda f=frmt, prog=self.prog: self.create(format=f, prog=prog)
#    1798     )
#    1799     f = self.__dict__['create_' + frmt]
#    1800     f.__doc__ = (
#    1801         '''Refer to the docstring accompanying the'''
#    1802         ''''create' method for more information.'''
#    1803     )
#
# File c:\Program Files\Python311\Lib\site-packages\pydotplus\graphviz.py:1959, in Dot.create(self, prog, format)
#    1957     self.progs = find_graphviz()
#    1958     if self.progs is None:
# -> 1959         raise InvocationException(
#    1960             'GraphViz\'s executables not found')
#    1962 if prog not in self.progs:
#    1963     raise InvocationException(
#    1964         'GraphViz\'s executable "%s" not found' % prog)
#
# InvocationException: GraphViz's executables not found

# %%
## Lưu trữ cây quyết định vào file
graph.write_pdf( "./Output/DecisionTree_Iris.pdf")
graph.write_png( "./Output/DecisionTree_Iris.png")
with open( "./Output/DecisionTree_Iris.txt", "w") as f:
    f = tree.export_graphviz(clf, out_file = f, feature_names = X.columns, 
                                                class_names   = data.iris)
    print("Đã xuất file .TXT")
# Out:
# ---------------------------------------------------------------------------
# InvocationException                       Traceback (most recent call last)
# Cell In[19], line 2
#       1 ## Lưu trữ cây quyết định vào file
# ----> 2 graph.write_pdf( "./Output/DecisionTree_Iris.pdf")
#       3 graph.write_png( "./Output/DecisionTree_Iris.png")
#       4 with open( "./Output/DecisionTree_Iris.txt", "w") as f:
#
# File c:\Program Files\Python311\Lib\site-packages\pydotplus\graphviz.py:1810, in Dot.__init__.<locals>.<lambda>(path, f, prog)
#    1800     f.__doc__ = (
#    1801         '''Refer to the docstring accompanying the'''
#    1802         ''''create' method for more information.'''
#    1803     )
#    1805 for frmt in self.formats + ['raw']:
#    1806     self.__setattr__(
#    1807         'write_' + frmt,
#    1808         lambda path,
#    1809         f=frmt,
# -> 1810         prog=self.prog: self.write(path, format=f, prog=prog)
#    1811     )
#    1813     f = self.__dict__['write_' + frmt]
#    1814     f.__doc__ = (
#    1815         '''Refer to the docstring accompanying the'''
#    1816         ''''write' method for more information.'''
#    1817     )
#
# File c:\Program Files\Python311\Lib\site-packages\pydotplus\graphviz.py:1918, in Dot.write(self, path, prog, format)
#    1915         fobj.write(data)
#    1917     else:
# -> 1918         fobj.write(self.create(prog, format))
#    1919 finally:
#    1920     if close:
#
# File c:\Program Files\Python311\Lib\site-packages\pydotplus\graphviz.py:1959, in Dot.create(self, prog, format)
#    1957     self.progs = find_graphviz()
#    1958     if self.progs is None:
# -> 1959         raise InvocationException(
#    1960             'GraphViz\'s executables not found')
#    1962 if prog not in self.progs:
#    1963     raise InvocationException(
#    1964         'GraphViz\'s executable "%s" not found' % prog)
#
# InvocationException: GraphViz's executables not found

# %%
## Xem lại cây quyết định
photo = imageio.imread("./Output/DecisionTree_Iris.png")
plt.figure(figsize = (16, 16))
plt.imshow(photo)
plt.show()
# Out:
# <ipython-input-12-84a380ba3b79>:2: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   photo = imageio.imread(folder + "/Output/DecisionTree_Iris.png")

# %%
## Lưu trữ mô hình để khai thác về sau
jlb.dump(model,  './Output/DecisionTree_Iris.mdl')
# Out:
# ['/content/gdrive/My Drive/Edu/1. UEH/Machine Learning/Demo/Ch03 - Supervised Learning/Output/DecisionTree_Iris.mdl']

# %%
## Khai thác mô hình đã được huấn luyện để đoán (Test set)
model  = jlb.load('./Output/DecisionTree_Iris.mdl')

tiep = 'C'
while (tiep.upper() == 'C'):
    idx    = int(eval(input(f'Nhập chỉ số dòng từ 0 đến {X_test.shape[0]}: ')))
    idx    = idx % X_test.shape[0]
    X_new  = X_test[idx:idx + 1]
    y_pred = model.predict(X_new)
    print('Mẫu', X_new.to_string(), '    được dự đoán là', y_pred)
    tiep = input('Tiếp tục (C/K) ? ')
# Out:
# Nhập chỉ số dòng từ 0 đến 30: 11
# Mẫu    sepallength  sepalwidth  petallength  petalwidth
# 5          5.4         3.9          1.7         0.4     được dự đoán là ['Iris-setosa']
# Tiếp tục (C/K) ? c
# Nhập chỉ số dòng từ 0 đến 30: 17
# Mẫu     sepallength  sepalwidth  petallength  petalwidth
# 66          5.6         3.0          4.5         1.5     được dự đoán là ['Iris-versicolor']
# Tiếp tục (C/K) ? k

# %% [markdown]
# ---
# ## 2. **Phân lớp Social_Network_Ads**
# ---

# %%
## Tập tin dữ liệu Social_Network_Ads
data = pd.read_csv( './Data/Social_Network_Ads.csv')
print(data.head())
# Out:
#     User ID  Gender  Age  EstimatedSalary  EstimatedSalary_K  Purchased
# 0  15624510    Male   19            19000                 19          0
# 1  15810944    Male   35            20000                 20          0
# 2  15668575  Female   26            43000                 43          0
# 3  15603246  Female   27            57000                 57          0
# 4  15804002    Male   19            76000                 76          0

# %%
## Các features: Gender, Age, EstimatedSalary
X = data.drop(['User ID', 'EstimatedSalary_K', 'Purchased'], axis = 1)
X.head()

## Biến target: Purchased
y = data.Purchased

print(pd.concat([X, y], axis = 1).head())
# Out:
#    Gender  Age  EstimatedSalary  Purchased
# 0    Male   19            19000          0
# 1    Male   35            20000          0
# 2  Female   26            43000          0
# 3  Female   27            57000          0
# 4    Male   19            76000          0
